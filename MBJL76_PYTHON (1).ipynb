# %%
import csv
import pandas as pd
import numpy as np
import time
import tensorflow as tensorflow
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from tensorflow.keras import layers, models

#Read file path
df = pd.read_csv('Group14-Cleaned-File.csv')

# Separate features and target variable
X = df.drop('target', axis=1)  # Features
Y = df['target']  # Target variable

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

start_time=time.time()

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(7, activation='softmax'))


#Compiling the model
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])


#Data preprocess
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_test)

#Encoding the labels
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_test)

#Model Training 
history = model.fit(X_train_scaled, y_train_encoded, epochs=20,batch_size=40,validation_data=(X_val_scaled, y_val_encoded))


X_test_scaled = scaler.transform(X_test)
y_pred = np.argmax(model.predict(X_test_scaled), axis=-1)

 
y_pred_labels = label_encoder.inverse_transform(y_pred)

end_time=time.time()
# Accuracy Score
Accuracy = accuracy_score(y_test, y_pred_labels)
print(f'Test Accuracy: {Accuracy}')
print(end_time-start_time)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\pc\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\pc\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\pc\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/1000
# WARNING:tensorflow:From C:\Users\pc\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\pc\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 100/100 [==============================] - 3s 11ms/step - loss: 1.9626 - accuracy: 0.2465 - val_loss: 1.4510 - val_accuracy: 0.6790
# Epoch 2/1000
# 100/100 [==============================] - 0s 5ms/step - loss: 1.4426 - accuracy: 0.4700 - val_loss: 0.8861 - val_accuracy: 0.8610
# Epoch 3/1000
# 100/100 [==============================] - 1s 7ms/step - loss: 1.0604 - accuracy: 0.6255 - val_loss: 0.5168 - val_accuracy: 0.9050
# Epoch 4/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.8348 - accuracy: 0.6973 - val_loss: 0.3570 - val_accuracy: 0.9210
# Epoch 5/1000
# 100/100 [==============================] - 0s 5ms/step - loss: 0.7041 - accuracy: 0.7545 - val_loss: 0.2911 - val_accuracy: 0.9260
# Epoch 6/1000
# 100/100 [==============================] - 1s 5ms/step - loss: 0.6429 - accuracy: 0.7770 - val_loss: 0.2595 - val_accuracy: 0.9290
# Epoch 7/1000
# 100/100 [==============================] - 0s 5ms/step - loss: 0.5590 - accuracy: 0.8065 - val_loss: 0.2334 - val_accuracy: 0.9330
# Epoch 8/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5229 - accuracy: 0.8198 - val_loss: 0.2213 - val_accuracy: 0.9290
# Epoch 9/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.4985 - accuracy: 0.8298 - val_loss: 0.2121 - val_accuracy: 0.9310
# Epoch 10/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.4785 - accuracy: 0.8353 - val_loss: 0.2038 - val_accuracy: 0.9280
# Epoch 11/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.4471 - accuracy: 0.8495 - val_loss: 0.2004 - val_accuracy: 0.9300
# Epoch 12/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.4479 - accuracy: 0.8508 - val_loss: 0.1989 - val_accuracy: 0.9310
# Epoch 13/1000
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4120 - accuracy: 0.8677 - val_loss: 0.1965 - val_accuracy: 0.9300
# Epoch 14/1000
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4081 - accuracy: 0.8615 - val_loss: 0.1944 - val_accuracy: 0.9330
# Epoch 15/1000
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3979 - accuracy: 0.8627 - val_loss: 0.1903 - val_accuracy: 0.9380
# Epoch 16/1000
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3864 - accuracy: 0.8708 - val_loss: 0.1898 - val_accuracy: 0.9330
# Epoch 17/1000
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3904 - accuracy: 0.8700 - val_loss: 0.1911 - val_accuracy: 0.9320
# Epoch 18/1000
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3614 - accuracy: 0.8745 - val_loss: 0.1864 - val_accuracy: 0.9330
# Epoch 19/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3583 - accuracy: 0.8835 - val_loss: 0.1876 - val_accuracy: 0.9340
# Epoch 20/1000
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3698 - accuracy: 0.8783 - val_loss: 0.1843 - val_accuracy: 0.9350
# Epoch 21/1000
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3616 - accuracy: 0.8820 - val_loss: 0.1835 - val_accuracy: 0.9330
# Epoch 22/1000
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3392 - accuracy: 0.8880 - val_loss: 0.1802 - val_accuracy: 0.9350
# Epoch 23/1000
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3425 - accuracy: 0.8863 - val_loss: 0.1831 - val_accuracy: 0.9320
# Epoch 24/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3375 - accuracy: 0.8938 - val_loss: 0.1851 - val_accuracy: 0.9350
# Epoch 25/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3251 - accuracy: 0.8917 - val_loss: 0.1809 - val_accuracy: 0.9310
# Epoch 26/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3296 - accuracy: 0.8900 - val_loss: 0.1843 - val_accuracy: 0.9330
# Epoch 27/1000
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3184 - accuracy: 0.8978 - val_loss: 0.1834 - val_accuracy: 0.9350
# Epoch 28/1000
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3147 - accuracy: 0.9050 - val_loss: 0.1840 - val_accuracy: 0.9360
# Epoch 29/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2999 - accuracy: 0.8992 - val_loss: 0.1812 - val_accuracy: 0.9370
# Epoch 30/1000
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3025 - accuracy: 0.8990 - val_loss: 0.1832 - val_accuracy: 0.9360
# Epoch 31/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3084 - accuracy: 0.9007 - val_loss: 0.1820 - val_accuracy: 0.9360
# Epoch 32/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2878 - accuracy: 0.9065 - val_loss: 0.1815 - val_accuracy: 0.9370
# Epoch 33/1000
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3134 - accuracy: 0.8982 - val_loss: 0.1807 - val_accuracy: 0.9370
# Epoch 34/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.3026 - accuracy: 0.9007 - val_loss: 0.1832 - val_accuracy: 0.9380
# Epoch 35/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2984 - accuracy: 0.9038 - val_loss: 0.1814 - val_accuracy: 0.9400
# Epoch 36/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2953 - accuracy: 0.9038 - val_loss: 0.1804 - val_accuracy: 0.9360
# Epoch 37/1000
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2990 - accuracy: 0.9085 - val_loss: 0.1824 - val_accuracy: 0.9380
# Epoch 38/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.2997 - accuracy: 0.9038 - val_loss: 0.1793 - val_accuracy: 0.9410
# Epoch 39/1000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2905 - accuracy: 0.9057 - val_loss: 0.1792 - val_accuracy: 0.9390
# Epoch 40/1000
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3017 - accuracy: 0.9068 - val_loss: 0.1805 - val_accuracy: 0.9400
# Epoch 41/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.2851 - accuracy: 0.9060 - val_loss: 0.1832 - val_accuracy: 0.9390
# Epoch 42/1000
#  97/100 [============================>.] - ETA: 0s - loss: 0.2778 - accuracy: 0.9162
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 50
#      47 y_val_encoded = label_encoder.transform(y_test)
#      49 #Model Training
# ---> 50 history = model.fit(X_train_scaled, y_train_encoded, epochs=1000,batch_size=40,validation_data=(X_val_scaled, y_val_encoded))
#      53 X_test_scaled = scaler.transform(X_test)
#      54 y_pred = np.argmax(model.predict(X_test_scaled), axis=-1)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\training.py:1856, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1840 if getattr(self, "_eval_data_handler", None) is None:
#    1841     self._eval_data_handler = data_adapter.get_data_handler(
#    1842         x=val_x,
#    1843         y=val_y,
#    (...)
#    1854         pss_evaluation_shards=self._pss_evaluation_shards,
#    1855     )
# -> 1856 val_logs = self.evaluate(
#    1857     x=val_x,
#    1858     y=val_y,
#    1859     sample_weight=val_sample_weight,
#    1860     batch_size=validation_batch_size or batch_size,
#    1861     steps=validation_steps,
#    1862     callbacks=callbacks,
#    1863     max_queue_size=max_queue_size,
#    1864     workers=workers,
#    1865     use_multiprocessing=use_multiprocessing,
#    1866     return_dict=True,
#    1867     _use_cached_eval_dataset=True,
#    1868 )
#    1869 val_logs = {
#    1870     "val_" + name: val for name, val in val_logs.items()
#    1871 }
#    1872 epoch_logs.update(val_logs)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\training.py:2296, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2292             with tf.profiler.experimental.Trace(
#    2293                 "test", step_num=step, _r=1
#    2294             ):
#    2295                 callbacks.on_test_batch_begin(step)
# -> 2296                 logs = test_function_runner.run_step(
#    2297                     dataset_or_iterator,
#    2298                     data_handler,
#    2299                     step,
#    2300                     self._pss_evaluation_shards,
#    2301                 )
#    2303 logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    2304 # Override with model metrics instead of last step logs
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\training.py:4108, in _TestFunction.run_step(self, dataset_or_iterator, data_handler, step, unused_shards)
#    4107 def run_step(self, dataset_or_iterator, data_handler, step, unused_shards):
# -> 4108     tmp_logs = self._function(dataset_or_iterator)
#    4109     if data_handler.should_sync:
#    4110         context.async_wait()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:877, in Function._call(self, *args, **kwds)
#     874 self._lock.release()
#     875 # In this case we have not created variables on the first call. So we can
#     876 # run the first trace but we should fail if variables are created.
# --> 877 results = tracing_compilation.call_function(
#     878     args, kwds, self._variable_creation_config
#     879 )
#     880 if self._created_variables:
#     881   raise ValueError("Creating variables on a non-first call to a function"
#     882                    " decorated with tf.function.")
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
